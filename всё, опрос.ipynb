# %%
import tkinter as tk

k=0

def open_easyquiz():
    window = tk.Tk()
    window.title("15 Questions")
    window.geometry("1000x300")
    def inst():
        t = tk.Label(window, text="Будут предоставлены различные слова, персонажи, моменты из аниме: нужно выбрать 1 правильный ответ")
        t.pack()


    def start():
        
        w1=2
        w2=3
        w3=1
        w4=1
        w5=3
        w6=1
        w7=2
        w8=2
        w9=3
        w10=1
        w11=2
        w12=1
        w13=2
        w14=3
        w15=2  
        
        

        
        def kj():
            global k
            
            x15 = float(entry_15.get())
            if (x15==w15):
                k=k+1
                
            results = tk.Tk()
            results.title("results")
            if (13<=k<=15):
                rs = tk.Label(results, text=" Молодец, ты действительно ас в аниме. Так держать")
                rs.pack() 
            if (8<=k<=12):
                mn = tk.Label(results, text="Ооо, неплохо, однако есть к чему стремиться")
                mn.pack()
            if (k<=7):
                xy = tk.Label(results, text=" Увы, но ты еще плохо разбираешься в этой сфере. но не расстраивайся. все еще впереди")
                xy.pack()
                
        def de():
            global k
            
            x14 = float(entry_14.get())
            if (x14==w14):
                k=k+1
                
            root = tk.Tk()
            root.title("Question15")
            q = tk.Label(root, text="Выберите вариант с жанрами аниме Домекано" )
            q.pack()
            a = tk.Label(root, text="1.) Ужасы, экшен, психология")
            a.pack()
            b = tk.Label(root, text="2.) Драма, романтика, школьная жизнь ")
            b.pack()
            c = tk.Label(root, text="3.) Комедия, триллер, фантстика")
            c.pack()
            entry_15 = tk.Entry(root, width=40)
            entry_15.pack()

            sub = tk.Button(root, text="Submit", command=kj)
            sub.pack()        
        def bn():
            global k
            
            x13 = float(entry_13.get())
            if (x13==w13):
                k=k+1 
                
            root = tk.Tk()
            root.title("Question14")
            q = tk.Label(root, text="Какой персонаж победил в аниме Война Двенадцати" )
            q.pack()
            a = tk.Label(root, text="1.) Конь")
            a.pack()
            b = tk.Label(root, text="2.) Кролик ")
            b.pack()
            c = tk.Label(root, text="3.) Крыса")
            c.pack()
            entry_14 = tk.Entry(root, width=40)
            entry_14.pack()

        
            sub = tk.Button(root, text="Submit", command=de)
            sub.pack()               
        def cv():
            global k
            
            x12 = float(entry_12.get())
            if (x12==w12):
                k=k+1
                
            root = tk.Tk()
            root.title("Question13")
            q = tk.Label(root, text="Кто убил семью Танджиро (Клинок, рассекающий демонов)" )
            q.pack()
            a = tk.Label(root, text="1.) Руи")
            a.pack()
            b = tk.Label(root, text="2.) Музан ")
            b.pack()
            c = tk.Label(root, text="3.) Кёгай")
            c.pack()
            entry_13 = tk.Entry(root, width=40)
            entry_13.pack()

        
            sub = tk.Button(root, text="Submit", command=bn)
            sub.pack()
        def zx():
            global k
            
            x11 = float(entry_11.get())
            if (x11==w11):
                k=k+1
                
            root = tk.Tk()
            root.title("Question12")
            q = tk.Label(root, text="Как зовут первого дворецкого-демона Алоиса? (Темный дворецкий)" )
            q.pack()
            a = tk.Label(root, text="1.) Клод")
            a.pack()
            b = tk.Label(root, text="2.) Тимбер")
            b.pack()
            c = tk.Label(root, text="3.) Себастьян")
            c.pack()
            entry_12 = tk.Entry(root, width=40)
            entry_12.pack()

         
            sub = tk.Button(root, text="Submit", command=cv)
            sub.pack()
        def kl():
            global k
            
            x10 = float(entry_10.get())
            if (x10==w10):
                k=k+1
                
            root = tk.Tk()
            root.title("Question11")
            q = tk.Label(root, text="В каком году вышел анимационный фильм Дитя погоды?" )
            q.pack()
            a = tk.Label(root, text="1.) 2018")
            a.pack()
            b = tk.Label(root, text="2.) 2019")
            b.pack()
            c = tk.Label(root, text="3.) 2017")
            c.pack()
            entry_11 = tk.Entry(root, width=40)
            entry_11.pack()

        
            sub = tk.Button(root, text="Submit", command=zx)
            sub.pack()
        def hj():
            global k
            
            x9 = float(entry_9.get())
            if (x9==w9):
                k=k+1
                
            root = tk.Tk()
            root.title("Question10")
            q = tk.Label(root, text="Какой любимый фрукт Рюка (Тетрадь смерти)" )
            q.pack()
            a = tk.Label(root, text="1.) Яблоко")
            a.pack()
            b = tk.Label(root, text="2.) Персик")
            b.pack()
            c = tk.Label(root, text="3.) Груша")
            c.pack()
            entry_10 = tk.Entry(root, width=40)
            entry_10.pack()

        
            sub = tk.Button(root, text="Submit", command=kl)
            sub.pack()
        def fg():
            global k
            
            x8 = float(entry_8.get())
            if (x8==w8):
                k=k+1
                
            root = tk.Tk()
            root.title("Question9")
            q = tk.Label(root, text="Из какого аниме Хацунэ Мику" )
            q.pack()
            a = tk.Label(root, text="1.)Живая любовь")
            a.pack()
            b = tk.Label(root, text="2.) Зомбиленд")
            b.pack()
            c = tk.Label(root, text="3.) Она не из аниме")
            c.pack()
            entry_9 = tk.Entry(root, width=40)
            entry_9.pack()

        
            sub = tk.Button(root, text="Submit", command=hj)
            sub.pack() 
        def asd():
            global k
            
            x7 = float(entry_7.get())
            if (x7==w7):
                k=k+1
                
            root = tk.Tk()
            root.title("Question8")
            q = tk.Label(root, text="Какое из нижеперечисленных аниме имеет лишь 1 сезон" )
            q.pack()
            a = tk.Label(root, text="1.) Безумный азарт")
            a.pack()
            b = tk.Label(root, text="2.) Убей или умри")
            b.pack()
            c = tk.Label(root, text="3.) Очень приятно, Бог")
            c.pack()
            entry_8 = tk.Entry(root, width=40)
            entry_8.pack()
 
        
            sub = tk.Button(root, text="Submit", command=fg)
            sub.pack() 
        def op():
            global k
            
            x6 = float(entry_6.get())
            if (x6==w6):
                k=k+1
                
            root = tk.Tk()
            root.title("Question7")
            q = tk.Label(root, text="К какому аниме относится Алисизация: Война в Подмирье?" )
            q.pack()
            a = tk.Label(root, text="1.) Хвост феи")
            a.pack()
            b = tk.Label(root, text="2.) Мастера Мечей Онлайн")
            b.pack()
            c = tk.Label(root, text="3.) Судьба")
            c.pack()
            entry_7 = tk.Entry(root, width=40)
            entry_7.pack()

        
            sub = tk.Button(root, text="Submit", command=asd)
            sub.pack()
        def ui():
            global k
            
            x5 = float(entry_5.get())
            if (x5==w5):
                k=k+1
                
            root = tk.Tk()
            root.title("Question6")
            q = tk.Label(root, text="Назовите группу, которая спела 1 опенинг аниме Токийский гуль")
            q.pack()
            a = tk.Label(root, text="1.) Ling toshite sigure")
            a.pack()
            b = tk.Label(root, text="2.) Fear and loathing in las vegas")
            b.pack()
            c = tk.Label(root, text="3.) Back-on")
            c.pack()
            entry_6 = tk.Entry(root, width=40) 
            entry_6.pack()

        
            sub = tk.Button(root, text="Submit", command=op)
            sub.pack()
        def ty():
            global k
            
            x4 = float(entry_4.get())
            if (x4==w4):
                k=k+1
                
            root = tk.Tk()
            root.title("Question5")
            q = tk.Label(root, text="Как звали духа меча Ичиго (Блич)?")
            q.pack()
            a = tk.Label(root, text="1.) Забимару")
            a.pack()
            b = tk.Label(root, text="2.) Мурамаса")
            b.pack()
            c = tk.Label(root, text="3.) Зангецу")
            c.pack()
            entry_5 = tk.Entry(root, width=40)
            entry_5.pack()

        
            sub = tk.Button(root, text="Submit", command=ui)
            sub.pack() 
        def er():
            global k
            
            x3 = float(entry_3.get())
            if (x3==w3):
                k=k+1
                
            root = tk.Tk()
            root.title("Question4")
            q = tk.Label(root, text="Кто убил Коро-сенсея(класс убийц)?")
            q.pack()
            a = tk.Label(root, text="1.) Нагиса")
            a.pack()
            b = tk.Label(root, text="2.) Каэде")
            b.pack()
            c = tk.Label(root, text="3.) Карма")
            c.pack()
            entry_4 = tk.Entry(root, width=40)
            entry_4.pack()

        
            sub = tk.Button(root, text="Submit", command=ty)
            sub.pack()
        def qw():
            global k
            
            x2 = float(entry_2.get())
            if (x2==w2):
                k=k+1
                
            root = tk.Tk()
            root.title("Question3")
            q = tk.Label(root, text="Какая способность у Чуи(Бродячие псы - литературные гении)?")
            q.pack()
            a = tk.Label(root, text="1.) гравитация")
            a.pack()
            b = tk.Label(root, text="2.) лечение")
            b.pack()
            c = tk.Label(root, text="3.) лишение магии")
            c.pack()
            entry_3 = tk.Entry(root, width=40)
            entry_3.pack()


        
            sub = tk.Button(root, text="Submit", command=er)
            sub.pack()

        def submit():
            global k
            
            x1 = float(entry_1.get())
            if (x1==w1):
                k=k+1
            
            root = tk.Tk()
            root.title("Question2")
            q = tk.Label(root, text="Какую игру предложили сыграть зверолюди Соре и Широ (Нет игры Нет жизни)?")
            q.pack()
            a = tk.Label(root, text="1.) шахматы")
            a.pack()
            b = tk.Label(root, text="2.) покер")
            b.pack()
            c = tk.Label(root, text="3.) компьютерные игры")
            c.pack()
            entry_2 = tk.Entry(root, width=40)
            entry_2.pack()

        
            sub = tk.Button(root, text="Submit", command=qw)
            sub.pack()


        root = tk.Tk()
        root.title("Question1")
        q = tk.Label(root, text="Что такое исекай?")
        q.pack()
        a = tk.Label(root, text="1.) повседневность") 
        a.pack()
        b = tk.Label(root, text="2.) параллельный мир")
        b.pack()
        c = tk.Label(root, text="3.) триллер")
        c.pack()
        entry_1 = tk.Entry(root, width=40)
        entry_1.pack()

        sub = tk.Button(root, text="Submit", command=submit)
        sub.pack()
                
        greet = tk.Label(window, text="добро пожаловать на аниме-квест")
        greet.pack()
        startButton = tk.Button(window, command=start, text="Start")
        startButton.pack()
        instr = tk.Button(window, text="Instructions", command=inst)
        instr.pack()
        end = tk.Button(window, text="Exit", command=window.destroy)
        end.pack()

        window.mainloop()
open_easyquiz()
